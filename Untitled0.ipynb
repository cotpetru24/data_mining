# %% [markdown]
# <a href="https://colab.research.google.com/github/cotpetru24/data_mining/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
dict = {'1st score' : [19, 20, 38, np.nan], '2nd score' : [10, 82, 68, np.nan], '3rd score' : [np.nan, 72, 13, 44]}
df = pd.DataFrame(dict)

#method to check for null value/missing value
df.isnull()
# Out:
#    1st score  2nd score  3rd score
# 0      False      False       True
# 1      False      False      False
# 2      False      False      False
# 3       True       True      False

# %% [markdown]
# # New section

# %%
df.head()
# Out:
#    1st score  2nd score  3rd score
# 0       19.0       10.0        NaN
# 1       20.0       82.0       72.0
# 2       38.0       68.0       13.0
# 3        NaN        NaN       44.0

# %%
df.shape
# Out:
# (4, 3)

# %%
df_2 = pd.read_csv("/content/Breast_Cancer_Data.csv")
df_2.head()
# Out:
#    mean_radius  mean_texture  mean_perimeter  mean_area  mean_smoothness
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030

# %%
df_2.isnull()
df_2.isnull().sum()
# Out:
# mean_radius        5
# mean_texture       1
# mean_perimeter     4
# mean_area          2
# mean_smoothness    5
# dtype: int64

# %%
df_2.isnull().sum().sum()
# Out:
# 17
