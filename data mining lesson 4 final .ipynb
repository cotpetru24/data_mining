# %% [markdown]
# <a href="https://colab.research.google.com/github/cotpetru24/data_mining/blob/main/data%20mining%20lesson%204%20final%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
dict = {'1st score' : [19, 20, 38, np.nan], '2nd score' : [10, 82, 68, np.nan], '3rd score' : [np.nan, 72, 13, 44]}
df = pd.DataFrame(dict)

#method to check for null value/missing value
df.isnull()
# Out:
#    1st score  2nd score  3rd score
# 0      False      False       True
# 1      False      False      False
# 2      False      False      False
# 3       True       True      False

# %% [markdown]
# # New section

# %%
df.head()
# Out:
#    1st score  2nd score  3rd score
# 0       19.0       10.0        NaN
# 1       20.0       82.0       72.0
# 2       38.0       68.0       13.0
# 3        NaN        NaN       44.0

# %%
df.shape
# Out:
# (4, 3)

# %%
df_2 = pd.read_csv("/content/Breast_Cancer_Data.csv")
df_2.head()
# Out:
#    mean_radius  mean_texture  mean_perimeter  mean_area  mean_smoothness
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030

# %%
df_2.isnull()
df_2.isnull().sum()
# Out:
# mean_radius        5
# mean_texture       1
# mean_perimeter     4
# mean_area          2
# mean_smoothness    5
# dtype: int64

# %%
df_2.isnull().sum().sum()
# Out:
# 17

# %%
#replace null values with the mean value of the entire dataset/ of all columns
#need to find why it didn't fill them
df_3 = df_2.fillna(value=df.mean())
df_3.isnull()
df_3.isnull().sum().sum()
# Out:
# 17

# %%
import pandas as pd

# Creating two DataFrames
act2_a = pd.read_csv("/content/Workshop 4 Activity 2 Data_a.csv")

act2_b = pd.read_csv("/content/Workshop 4 Activity 2 Data_b.csv")

# Merging the DataFrames on 'EmployeeID'
result = pd.merge(act2_a, act2_b, on='Student_ID', how='inner')

print(result)
# Out:
#    Student_ID  Award        City  Age Gender   Grade Employed
# 0           1     78  Birmingham   22      M   First        N
# 1           2     53    Coventry   24      M  Second        Y
# 2           3     68   Newcastle   21      M  Second        Y
# 3           4     28     Norwich   20      F    Fail        N
# 4           5     82       Leeds   45      M   First        Y
# 5           6     91  Manchester   32      F   First        N
# 6           7     65  Portsmouth   27      F  Second        N
# 7           8     44     Cardiff   34      M   Third        N
# 8           9     72     Glasgow   25      F   First        N
# 9          10     81     Ipswich   26      F   First        Y

# %%
from sklearn.preprocessing import LabelEncoder

labe_encoder = LabelEncoder()
#display only categorical data
act3 = pd.read_csv("/content/Workshop 4 Activity 3 Data.csv")
df_categorical = act3.select_dtypes(exclude=np.number)
df_categorical
# Out:
#    Gender   Grade Employed
# 0       M   First        N
# 1       M  Second        Y
# 2       M  Second        Y
# 3       F    Fail        N
# 4       M   First        Y
# 5       F   First        N
# 6       F  Second        N
# 7       M   Third        N
# 8       F   First        N
# 9       F   First        Y
# 10      M  Second        Y
# 11      F  Second        Y
# 12      F   First        N
# 13      F   Third        N
# 14      M   First        N
# 15      M   Third        N
# 16      F  Second        N
# 17      M  Second        N
# 18      M   First        N
# 19      M   Third        N

# %%
#identifu how many values a categorical data has
df_categorical.Grade.value_counts()
# Out:
# First     8
# Second    7
# Third     4
# Fail      1
# Name: Grade, dtype: int64

# %%
#how to replace categorical data with numerical values
df_categorical['Gender'].replace({'M': 1, 'F': 2}, inplace=True)
df_categorical
# Out:
#     Gender   Grade Employed
# 0        1   First        N
# 1        1  Second        Y
# 2        1  Second        Y
# 3        2    Fail        N
# 4        1   First        Y
# 5        2   First        N
# 6        2  Second        N
# 7        1   Third        N
# 8        2   First        N
# 9        2   First        Y
# 10       1  Second        Y
# 11       2  Second        Y
# 12       2   First        N
# 13       2   Third        N
# 14       1   First        N
# 15       1   Third        N
# 16       2  Second        N
# 17       1  Second        N
# 18       1   First        N
# 19       1   Third        N
